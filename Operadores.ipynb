# %% [markdown]
# Dicas para documentação de código:
#
# *   Não comentar códigos errados e nem em testes
# *   Usar # para comentar uma linha de código
# *   Para múltiplas linhas, usar a aspa tripla

# %%
"""
Este é um exemplo de cabeçalho
"""

# %% [markdown]
# ## Operadores Aritméticos

# %%
# Adição
10 + 2
# Out:
# 12

# %%
# Subtração
10 - 2
# Out:
# 8

# %%
# Multiplicação
10 * 2
# Out:
# 20

# %%
# Divisão
10 / 2
# Out:
# 5.0

# %%
# Divisão inteira
10 // 2
# Out:
# 5

# %%
# Resto da divisão
10 % 2
# Out:
# 0

# %%
# Potenciação
10 ** 2
# Out:
# 100

# %% [markdown]
# ## Operadores relacionais

# %%
# Menor
10 < 2
# Out:
# False

# %%
# Menor ou igual
10 <= 2
# Out:
# False

# %%
# Maior
10 > 2
# Out:
# True

# %%
# Maior ou igual
10 >= 2
# Out:
# True

# %%
# Igual
10 == 2
# Out:
# False

# %%
# Diferente
10 != 2
# Out:
# True

# %% [markdown]
# ## Operadores lógicos
#
# *   And
# *   Or
# *   Not

# %% [markdown]
# ### Tabela verdade

# %%
# And

print (10 > 2 and 4 < 6)  # V and V - V
print (10 > 2 and 4 > 6)  # V and F - F
print (10 < 2 and 4 < 6)  # V and F - F
print (10 < 2 and 4 > 6)  # F and F - F
# Out:
# True
# False
# False
# False

# %%
# Or

print (10 > 2 or 4 < 6)  # V or V - V
print (10 > 2 or 4 > 6)  # V or F - V
print (10 < 2 or 4 < 6)  # V or F - V
print (10 < 2 or 4 > 6)  # F or F - F
# Out:
# True
# True
# True
# False

# %%
# Not

not 10 > 2  # V - F
not 10 < 2  # F - V
